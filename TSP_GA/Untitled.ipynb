# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
file_path = "City_Dataset/city_name.txt"

with open(file_path, "r") as file:
    lines = file.readlines()

nameList = [line.strip() for line in lines]
nameList
# Out:
# ['Augsburg',
#  'Bielefeld',
#  'Bochum',
#  'Bremen1',
#  'Darmstadt',
#  'Essen',
#  'Freiburg',
#  'Giessen',
#  'Hamburg',
#  'Hannover',
#  'Heilbronn',
#  'Kaiserslautern',
#  'Karlsruhe',
#  'Kassel',
#  'Kempten',
#  'Koblenz',
#  'Koeln',
#  'Landshut',
#  'Lichtenfels',
#  'Mainz',
#  'Muenchen',
#  'Muenster',
#  'Neuss',
#  'Nuernburg',
#  'Oldenburg',
#  'Regensburg',
#  'Rendsburg',
#  'Stuttgart',
#  'Ulm',
#  'Wuerzburg',
#  'Aachen',
#  'Ansbach',
#  'Aschaffenburg',
#  'Bamberg',
#  'Bayreuth',
#  'Bonn',
#  'Braunschweig',
#  'Bremen2',
#  'Coburg',
#  'Dortmund',
#  'Duesseldorf',
#  'Duisburg',
#  'Erlangen',
#  'Frankfurt',
#  'Fulda',
#  'Fuerth',
#  'Gelsen-Kirchen',
#  'Gummersburg',
#  'Hagen',
#  'Hersbruck',
#  'Ingolstadt',
#  'Kiel',
#  'Mannheim',
#  'Marburg',
#  'Offenburg',
#  'Osnabrueck',
#  'Reutlingen',
#  'Saarbruecken',
#  'Siegen']

# %%
df_data = pd.read_csv("City_Dataset/wg59_dist.csv", header=None, names=nameList)
df_data.index = nameList
df_data.shape
# Out:
# (59, 59)

# %%
df_data
# Out:
#                 Augsburg  Bielefeld  Bochum  Bremen1  Darmstadt  Essen  \
# Augsburg               0        146     145      181         77    147
# Bielefeld            146          0      35       40         80     40
# Bochum               145         35       0       69         69      5
# Bremen1              181         40      69        0        120     73
# Darmstadt             77         80      69      120          0     71
# Essen                147         40       5       73         71      0
# Freiburg              76        148     129      189         70    128
# Giessen              100         51      45       91         29     48
# Hamburg              195         67     100       31        141    104
# Hannover             151         30      66       33         96     71
# Heilbronn             49        109     100      149         31    102
# Kaiserslautern        84         99      79      140         27     79
# ...

# %%
df_codata = pd.read_csv("City_Dataset/wg59_coordinates.csv", header=None, names=['X', 'Y'])
df_codata.index = nameList
df_codata.shape
# Out:
# (59, 2)

# %%
df_codata
# Out:
#                  X    Y
# Augsburg        54  -65
# Bielefeld        0   71
# Bochum         -31   53
# Bremen1          8  111
# Darmstadt        1   -9
# Essen          -36   52
# Freiburg       -22  -76
# Giessen          0   20
# Hamburg         34  129
# Hannover        28   84
# Heilbronn       12  -38
# Kaiserslautern -21  -26
# Karlsruhe       -6  -41
# Kassel          21   45
# Kempten         38  -90
# Koblenz        -24   10
# Koeln          -38   35
# Landshut        86  -57
# Lichtenfels     58   -1
# Mainz           -9   -3
# Muenchen        70  -74
# Muenster       -20   70
# Neuss          -43   44
# Nuernburg       59  -26
# Oldenburg       -5  114
# Regensburg      83  -41
# Rendsburg       27  153
# Stuttgart       12  -49
# Ulm             30  -65
# Wuerzburg       31  -12
# Aachen         -57   28
# Ansbach         44  -28
# Aschaffenburg    7   -7
# Bamberg         54   -8
# Bayreuth        65   -8
# Bonn           -35   25
# Braunschweig    46   79
# ...
